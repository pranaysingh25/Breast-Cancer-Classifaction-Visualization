# %%
#importing essential libraries
import numpy as np
import pandas as pd 
import matplotlib 
import matplotlib.pyplot as plt

# %%
#loading the dataset
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
#splitting our data into training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target)

# %%
#checking the shape of the data
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((426, 30), (143, 30), (426,), (143,))

# %%
#the names of the feature used
feature_names = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean','smoothness_mean','compactness_mean',
                                           'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal dimension_mean', 
                                           'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se',
                                           'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 
                                           'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst',
                                           'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal dimension_worst' ]

# %%
X_train = pd.DataFrame(X_train, columns = feature_names)

# %%
X_train.head(5)
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.08         27.15          111.20      930.9          0.09898
# 1        14.20         20.53           92.41      618.4          0.08931
# 2        19.21         18.57          125.50     1152.0          0.10530
# 3        18.31         18.58          118.60     1041.0          0.08588
# 4        20.44         21.78          133.80     1293.0          0.09150
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.11100         0.10070              0.06431         0.1793
# 1           0.11080         0.05063              0.03058         0.1506
# 2           0.12670         0.13230              0.08994         0.1917
# 3           0.08468         0.08169              0.05814         0.1621
# 4           0.11310         0.09799              0.07785         0.1618
#
#    fractal dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.06281  ...         22.96          34.49            152.1
# 1                 0.06009  ...         16.45          27.26            112.1
# 2                 0.05961  ...         26.14          28.14            170.1
# 3                 0.05425  ...         21.31          26.36            139.2
# 4                 0.05557  ...         24.31          26.37            161.2
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      1648.0            0.1600             0.2444           0.2639
# 1       828.5            0.1153             0.3429           0.2512
# 2      2145.0            0.1624             0.3511           0.3879
# 3      1410.0            0.1234             0.2445           0.3538
# 4      1780.0            0.1327             0.2376           0.2702
#
#    concave points_worst  symmetry_worst  fractal dimension_worst
# 0                0.1555          0.3010                  0.09060
# 1                0.1339          0.2534                  0.07858
# 2                0.2091          0.3537                  0.08294
# 3                0.1571          0.3206                  0.06938
# 4                0.1765          0.2609                  0.06735
#
# [5 rows x 30 columns]

# %%
#lets see if there are any missing values
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 30 columns):
# radius_mean                426 non-null float64
# texture_mean               426 non-null float64
# perimeter_mean             426 non-null float64
# area_mean                  426 non-null float64
# smoothness_mean            426 non-null float64
# compactness_mean           426 non-null float64
# concavity_mean             426 non-null float64
# concave points_mean        426 non-null float64
# symmetry_mean              426 non-null float64
# fractal dimension_mean     426 non-null float64
# radius_se                  426 non-null float64
# texture_se                 426 non-null float64
# perimeter_se               426 non-null float64
# area_se                    426 non-null float64
# smoothness_se              426 non-null float64
# compactness_se             426 non-null float64
# concavity_se               426 non-null float64
# concave points_se          426 non-null float64
# symmetry_se                426 non-null float64
# fractal_dimension_se       426 non-null float64
# radius_worst               426 non-null float64
# texture_worst              426 non-null float64
# perimeter_worst            426 non-null float64
# area_worst                 426 non-null float64
# smoothness_worst           426 non-null float64
# compactness_worst          426 non-null float64
# concavity_worst            426 non-null float64
# concave points_worst       426 non-null float64
# symmetry_worst             426 non-null float64
# fractal dimension_worst    426 non-null float64
# dtypes: float64(30)
# memory usage: 100.0 KB

# %%
#checking the scale of the data
X_train.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   426.000000    426.000000      426.000000   426.000000
# mean     14.014251     19.166948       91.201221   642.819249
# std       3.412527      4.174580       23.540942   336.797068
# min       7.691000      9.710000       47.920000   170.400000
# 25%      11.672500     16.170000       74.690000   417.575000
# 50%      13.275000     18.810000       86.040000   545.750000
# 75%      15.647500     21.597500      102.875000   758.600000
# max      27.420000     39.280000      186.900000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       426.000000        426.000000      426.000000           426.000000
# mean          0.095869          0.103110        0.086949             0.047936
# std           0.013615          0.051467        0.077995             0.037401
# min           0.052630          0.026500        0.000000             0.000000
# 25%           0.086380          0.064035        0.028640             0.020280
# 50%           0.095865          0.092350        0.060015             0.033455
# 75%           0.104400          0.129875        0.120400             0.070350
# max           0.144700          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal dimension_mean  ...  radius_worst  \
# count     426.000000              426.000000  ...    426.000000
# mean        0.181580                0.062792  ...     16.104404
# std         0.027487                0.006673  ...      4.698369
# min         0.116700                0.049960  ...      8.678000
# 25%         0.163025                0.058265  ...     12.920000
# 50%         0.179200                0.061955  ...     14.875000
# 75%         0.195625                0.066380  ...     18.197500
# max         0.304000                0.097440  ...     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     426.000000       426.000000   426.000000        426.000000
# mean       25.479202       106.125023   861.342019          0.132069
# std         5.962712        32.519140   554.784170          0.022003
# min        12.020000        54.490000   223.600000          0.084090
# 25%        21.037500        83.702500   511.000000          0.117125
# 50%        25.240000        96.930000   674.950000          0.131600
# 75%        29.372500       123.500000  1024.000000          0.146000
# max        47.160000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         426.000000       426.000000            426.000000
# mean            0.250623         0.267762              0.113816
# std             0.149873         0.201717              0.064913
# min             0.043270         0.000000              0.000000
# 25%             0.140675         0.112975              0.063533
# 50%             0.213850         0.225450              0.100015
# 75%             0.336450         0.378425              0.157250
# max             0.937900         1.170000              0.273300
#
#        symmetry_worst  fractal dimension_worst
# count      426.000000               426.000000
# mean         0.289977                 0.083707
# std          0.061236                 0.016660
# min          0.156500                 0.055040
# 25%          0.250525                 0.071857
# 50%          0.283100                 0.080640
# 75%          0.318625                 0.092052
# max          0.663800                 0.173000
#
# [8 rows x 30 columns]

# %%
#lets see how our data looks like on the graph
X_train.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#we need to scale the data
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
X_train = pd.DataFrame(X_train, columns= feature_names)
X_test = pd.DataFrame(X_test, columns = feature_names)

# %% [markdown]
# Just a fun part! : Data visualization using Dimentionality Reduction

# %%
#making the copy of our data before any transformation
X_train_c = X_train.copy()

# %%
#lets try first The PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
X_train2d = pca.fit_transform(X_train_c)

# %%
#about 63% of the variance has been preserved by only 2 features!
pca.explained_variance_ratio_
# Out:
# array([0.44979912, 0.18071727])

# %%
#lets now finally plot these components against the labels 
plt.figure(figsize=(12,8))
plt.scatter(X_train2d[:,0], X_train2d[:,1], c=y_train, cmap='jet')
plt.axis('off')
plt.colorbar()
plt.show()

# %% [markdown]
# looks pretty clear! It won't be a bad idea using TSNE as well. Let's do it now!

# %%
#TSNE
from sklearn.manifold import TSNE

tsne= TSNE(n_components = 2, random_state = 42)
X_train_tsne= tsne.fit_transform(X_train_c)

# %%
#lets see how far tsne gets
plt.figure(figsize=(12,8))
plt.scatter(X_train_tsne[:,0], X_train_tsne[:,1], c=y_train, cmap='jet')
plt.axis('off')
plt.colorbar()
plt.show()

# %% [markdown]
# wow! that looks even neat! there are just a very few outliers lying around, rest the clusters are well separated.

# %% [markdown]
# Now let's fit a few good models on our data to see how they perform.

# %%
#starting with Stochastic Gradient Descent classifier
from sklearn.linear_model import SGDClassifier
sgd_clf = SGDClassifier(random_state=42, early_stopping= True, n_iter_no_change=10)

# %%
#using cross validation 
from sklearn.model_selection import cross_val_score
cvs = cross_val_score(sgd_clf, X_train, y_train, cv=5)
print(cvs)
print(cvs.mean())
print(cvs.std())
# Out:
# [0.95348837 0.95294118 0.97647059 0.96470588 0.94117647]
# 0.9577564979480165
# 0.011956693902445824

# %% [markdown]
# that's not a bad score!

# %%
#trying Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt_clf = DecisionTreeClassifier(random_state=42)
cvs2 = cross_val_score(dt_clf, X_train, y_train, cv=5)
print(cvs2)
print(cvs2.mean())
print(cvs2.std())
# Out:
# [0.90697674 0.89411765 0.91764706 0.94117647 0.95294118]
# 0.9225718194254446
# 0.0216588571074403

# %% [markdown]
# Its not better than the SGD classifier.

# %%
#lets try random forest with as many as 100 decition trees!
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(random_state=42, n_estimators=100)

cvs3 = cross_val_score(rfc, X_train, y_train, cv=5)
print(cvs3)
print(cvs3.mean())
print(cvs3.std())
# Out:
# [0.96511628 0.95294118 0.96470588 0.96470588 0.96470588]
# 0.962435020519836
# 0.004749582352969165

# %% [markdown]
# now, let's move forward with Neural Network, a shallow one.

# %%
#a shallow NN with 2 hidden layers
#defining a NN using Sequential API
from tensorflow import keras
model = keras.models.Sequential([
    keras.layers.Dense(300, activation = 'relu', input_shape=(30,)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
#compiling our model with same loss and accuracy metric used for SGD
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
#have a look how it looks
model.summary()
keras.utils.plot_model(model)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 300)               9300
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 39,501
# Trainable params: 39,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
#let's train it
early_stopping_cb = keras.callbacks.EarlyStopping(patience=7, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=35, validation_split=0.1, callbacks= [early_stopping_cb])
# Out:
# Train on 383 samples, validate on 43 samples
# Epoch 1/35
# 383/383 [==============================] - 1s 2ms/sample - loss: 0.6614 - accuracy: 0.4491 - val_loss: 0.6170 - val_accuracy: 0.7907
# Epoch 2/35
# 383/383 [==============================] - 0s 92us/sample - loss: 0.5423 - accuracy: 0.8329 - val_loss: 0.5062 - val_accuracy: 0.9070
# Epoch 3/35
# 383/383 [==============================] - 0s 90us/sample - loss: 0.4603 - accuracy: 0.9191 - val_loss: 0.4276 - val_accuracy: 0.9302
# Epoch 4/35
# 383/383 [==============================] - 0s 91us/sample - loss: 0.3997 - accuracy: 0.9295 - val_loss: 0.3691 - val_accuracy: 0.9535
# Epoch 5/35
# 383/383 [==============================] - 0s 90us/sample - loss: 0.3535 - accuracy: 0.9321 - val_loss: 0.3243 - val_accuracy: 0.9535
# Epoch 6/35
# 383/383 [==============================] - 0s 96us/sample - loss: 0.3177 - accuracy: 0.9426 - val_loss: 0.2890 - val_accuracy: 0.9535
# Epoch 7/35
# 383/383 [==============================] - 0s 91us/sample - loss: 0.2891 - accuracy: 0.9504 - val_loss: 0.2608 - val_accuracy: 0.9535
# Epoch 8/35
# 383/383 [==============================] - 0s 91us/sample - loss: 0.2660 - accuracy: 0.9504 - val_loss: 0.2377 - val_accuracy: 0.9535
# Epoch 9/35
# 383/383 [==============================] - 0s 91us/sample - loss: 0.2469 - accuracy: 0.9504 - val_loss: 0.2186 - val_accuracy: 0.9535
# Epoch 10/35
# 383/383 [==============================] - 0s 97us/sample - loss: 0.2309 - accuracy: 0.9504 - val_loss: 0.2026 - val_accuracy: 0.9535
# Epoch 11/35
# 383/383 [==============================] - 0s 92us/sample - loss: 0.2172 - accuracy: 0.9530 - val_loss: 0.1890 - val_accuracy: 0.9535
# Epoch 12/35
# 383/383 [==============================] - 0s 90us/sample - loss: 0.2056 - accuracy: 0.9530 - val_loss: 0.1773 - val_accuracy: 0.9535
# Epoch 13/35
# 383/383 [==============================] - 0s 89us/sample - loss: 0.1954 - accuracy: 0.9530 - val_loss: 0.1672 - val_accuracy: 0.9535
# Epoch 14/35
# 383/383 [==============================] - 0s 89us/sample - loss: 0.1865 - accuracy: 0.9556 - val_loss: 0.1584 - val_accuracy: 0.9535
# Epoch 15/35
# 383/383 [==============================] - 0s 90us/sample - loss: 0.1788 - accuracy: 0.9582 - val_loss: 0.1506 - val_accuracy: 0.9535
# Epoch 16/35
# 383/383 [==============================] - 0s 89us/sample - loss: 0.1718 - accuracy: 0.9608 - val_loss: 0.1437 - val_accuracy: 0.9535
# Epoch 17/35
# 383/383 [==============================] - 0s 89us/sample - loss: 0.1655 - accuracy: 0.9608 - val_loss: 0.1376 - val_accuracy: 0.9535
# Epoch 18/35
# 383/383 [==============================] - 0s 92us/sample - loss: 0.1598 - accuracy: 0.9608 - val_loss: 0.1320 - val_accuracy: 0.9535
# Epoch 19/35
# 383/383 [==============================] - 0s 94us/sample - loss: 0.1547 - accuracy: 0.9634 - val_loss: 0.1269 - val_accuracy: 0.9535
# Epoch 20/35
# 383/383 [==============================] - 0s 94us/sample - loss: 0.1499 - accuracy: 0.9634 - val_loss: 0.1224 - val_accuracy: 0.9767
# Epoch 21/35
# 383/383 [==============================] - 0s 93us/sample - loss: 0.1456 - accuracy: 0.9634 - val_loss: 0.1182 - val_accuracy: 0.9767
# Epoch 22/35
# 383/383 [==============================] - 0s 90us/sample - loss: 0.1416 - accuracy: 0.9661 - val_loss: 0.1144 - val_accuracy: 0.9767
# Epoch 23/35
# 383/383 [==============================] - 0s 92us/sample - loss: 0.1378 - accuracy: 0.9661 - val_loss: 0.1109 - val_accuracy: 0.9767
# Epoch 24/35
# 383/383 [==============================] - 0s 92us/sample - loss: 0.1344 - accuracy: 0.9687 - val_loss: 0.1076 - val_accuracy: 0.9767
# Epoch 25/35
# 383/383 [==============================] - 0s 92us/sample - loss: 0.1312 - accuracy: 0.9687 - val_loss: 0.1046 - val_accuracy: 0.9767
# Epoch 26/35
# 383/383 [==============================] - 0s 90us/sample - loss: 0.1282 - accuracy: 0.9687 - val_loss: 0.1019 - val_accuracy: 0.9767
# Epoch 27/35
# 383/383 [==============================] - 0s 93us/sample - loss: 0.1253 - accuracy: 0.9713 - val_loss: 0.0993 - val_accuracy: 0.9767
# Epoch 28/35
# 383/383 [==============================] - 0s 88us/sample - loss: 0.1226 - accuracy: 0.9713 - val_loss: 0.0968 - val_accuracy: 0.9767
# Epoch 29/35
# 383/383 [==============================] - 0s 92us/sample - loss: 0.1202 - accuracy: 0.9713 - val_loss: 0.0945 - val_accuracy: 0.9767
# Epoch 30/35
# 383/383 [==============================] - 0s 86us/sample - loss: 0.1179 - accuracy: 0.9713 - val_loss: 0.0924 - val_accuracy: 0.9767
# Epoch 31/35
# 383/383 [==============================] - 0s 94us/sample - loss: 0.1157 - accuracy: 0.9739 - val_loss: 0.0904 - val_accuracy: 0.9767
# Epoch 32/35
# 383/383 [==============================] - 0s 93us/sample - loss: 0.1135 - accuracy: 0.9739 - val_loss: 0.0885 - val_accuracy: 0.9767
# Epoch 33/35
# 383/383 [==============================] - 0s 90us/sample - loss: 0.1115 - accuracy: 0.9739 - val_loss: 0.0867 - val_accuracy: 0.9767
# Epoch 34/35
# 383/383 [==============================] - 0s 90us/sample - loss: 0.1096 - accuracy: 0.9765 - val_loss: 0.0850 - val_accuracy: 0.9767
# Epoch 35/35
# 383/383 [==============================] - 0s 91us/sample - loss: 0.1078 - accuracy: 0.9765 - val_loss: 0.0834 - val_accuracy: 0.9767

# %% [markdown]
# So, NN perfoms best than every other classifier!

# %%
#we have the 'losses' history.history, we can plot it after converting it into dataframe.
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %%
#now evaluating on the test data
model.evaluate(X_test, y_test)
# Out:
# 143/143 [==============================] - 0s 72us/sample - loss: 0.0928 - accuracy: 0.9650
# [0.09275403492465302, 0.96503496]

# %% [markdown]
# **96% accuracy with 9% loss is not a bad report card! **
